# %%
import hashlib

# Create a hash object using MD5 algorithm
hash_object = hashlib.md5()

# Update the hash object with a message
hash_object.update(b"Hello, world!")

# Get the hexadecimal digest of the hash
hex_dig = hash_object.hexdigest()

print(hex_dig)

# Update the hash object with a message
hash_object.update(b"Butterfly!")

# Get the hexadecimal digest of the hash
hex_dig = hash_object.hexdigest()

print(hex_dig)

# Update the hash object with a message
hash_object.update(b"Which way did they go?")

# Get the hexadecimal digest of the hash
hex_dig = hash_object.hexdigest()

print(hex_dig)
# Out:
# 6cd3556deb0da54bca060b4c39479839
# 8a2f51207269787badf21399163a54cb
# 6d4e497321e0399c0819118b1267ed64
